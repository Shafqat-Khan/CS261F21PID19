# %%
from PyQt5 import QtCore, QtGui, QtWidgets
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import time
import sys
import csv

# %%
class Ui_MainWindow(object):
    def setupUi(self, MainWindow):
        n = 100
        MainWindow.setObjectName("MainWindow")
        MainWindow.resize(759, 513)
        MainWindow.setStyleSheet("selection-background-color: rgb(255, 170, 255);\n"
"background-color: rgb(255, 170, 255);")
        self.centralwidget = QtWidgets.QWidget(MainWindow)
        self.centralwidget.setStyleSheet("background-color: rgb(255, 170, 255);")
        self.centralwidget.setObjectName("centralwidget")
        self.tableWidget = QtWidgets.QTableWidget(self.centralwidget)
        self.tableWidget.setGeometry(QtCore.QRect(0, 140, 751, 351))
        self.tableWidget.setAutoFillBackground(True)
        self.tableWidget.setStyleSheet("background-color: rgb(255, 255, 255);")
        self.tableWidget.setRowCount(10000)
        self.tableWidget.setObjectName("tableWidget")
        self.tableWidget.setColumnCount(7)
        item = QtWidgets.QTableWidgetItem()
        self.tableWidget.setHorizontalHeaderItem(0, item)
        item = QtWidgets.QTableWidgetItem()
        self.tableWidget.setHorizontalHeaderItem(1, item)
        item = QtWidgets.QTableWidgetItem()
        self.tableWidget.setHorizontalHeaderItem(2, item)
        item = QtWidgets.QTableWidgetItem()
        self.tableWidget.setHorizontalHeaderItem(3, item)
        item = QtWidgets.QTableWidgetItem()
        self.tableWidget.setHorizontalHeaderItem(4, item)
        item = QtWidgets.QTableWidgetItem()
        self.tableWidget.setHorizontalHeaderItem(5, item)
        item = QtWidgets.QTableWidgetItem()
        self.tableWidget.setHorizontalHeaderItem(6, item)
        self.pushButton = QtWidgets.QPushButton(self.centralwidget)
        self.pushButton.setGeometry(QtCore.QRect(70, 0, 71, 31))
        self.pushButton.setAutoFillBackground(False)
        self.pushButton.setStyleSheet("background-color: rgb(85, 255, 127);\n"
"font: 87 10pt \"Arial Black\";")
        self.pushButton.setObjectName("pushButton")
        self.pushButton.clicked.connect(self.scrap)
        self.pushButton.clicked.connect(lambda status, n_size = n: self.run(n_size))
        self.comboBox = QtWidgets.QComboBox(self.centralwidget)
        self.comboBox.setGeometry(QtCore.QRect(400, 60, 131, 21))
        self.comboBox.setStyleSheet("background-color: rgb(0, 255, 127);")
        self.comboBox.setObjectName("comboBox")
        self.comboBox.addItem("")
        self.comboBox.addItem("")
        self.comboBox.addItem("")
        self.comboBox.addItem("")
        self.comboBox.addItem("")
        self.comboBox.addItem("")
        self.comboBox.addItem("")
        self.label = QtWidgets.QLabel(self.centralwidget)
        self.label.setGeometry(QtCore.QRect(400, 20, 101, 31))
        self.label.setStyleSheet("background-color: rgb(0, 255, 127);\n"
"font: 75 9pt \"MS Shell Dlg 2\";")
        self.label.setObjectName("label")
        self.pushButton_2 = QtWidgets.QPushButton(self.centralwidget)
        self.pushButton_2.setGeometry(QtCore.QRect(0, 0, 71, 31))
        self.pushButton_2.setStyleSheet("background-color: rgb(0, 255, 127);\n"
"font: 87 10pt \"Arial Black\";")
        self.pushButton_2.setObjectName("pushButton_2")
        self.pushButton_2.clicked.connect(self.loadData)
        self.progressBar = QtWidgets.QProgressBar(self.centralwidget)
        self.progressBar.setGeometry(QtCore.QRect(90, 80, 291, 31))
        self.progressBar.setToolTip("")
        self.progressBar.setAccessibleName("")
        self.progressBar.setAutoFillBackground(False)
        self.progressBar.setStyleSheet("color: rgb(170, 0, 0);\n"
"font: 87 8pt \"Arial Black\";")
        self.progressBar.setRange(0,n)
        self.progressBar.setTextVisible(True)
        self.progressBar.setObjectName("progressBar")
        self.pushButton_3 = QtWidgets.QPushButton(self.centralwidget)
        self.pushButton_3.setGeometry(QtCore.QRect(10, 100, 61, 31))
        self.pushButton_3.setStyleSheet("background-color: rgb(0, 255, 127);\n"
"font: 87 8pt \"Arial Black\";")
        self.pushButton_3.setObjectName("pushButton_3")
        self.pushButton_4 = QtWidgets.QPushButton(self.centralwidget)
        self.pushButton_4.setGeometry(QtCore.QRect(10, 60, 61, 31))
        self.pushButton_4.setStyleSheet("background-color: rgb(0, 255, 127);\n"
"font: 87 8pt \"Arial Black\";")
        self.pushButton_4.setObjectName("pushButton_4")
        self.pushButton_5 = QtWidgets.QPushButton(self.centralwidget)
        self.pushButton_5.setGeometry(QtCore.QRect(400, 90, 71, 31))
        self.pushButton_5.setStyleSheet("background-color: rgb(0, 255, 127);\n"
"font: 87 10pt \"Arial Black\";")
        self.pushButton_5.setObjectName("pushButton_5")
        self.label_2 = QtWidgets.QLabel(self.centralwidget)
        self.label_2.setGeometry(QtCore.QRect(550, 20, 101, 31))
        self.label_2.setStyleSheet("background-color: rgb(0, 255, 127);\n"
"font: 75 9pt \"MS Shell Dlg 2\";")
        self.label_2.setObjectName("label_2")
        self.comboBox_2 = QtWidgets.QComboBox(self.centralwidget)
        self.comboBox_2.setGeometry(QtCore.QRect(550, 60, 131, 21))
        self.comboBox_2.setStyleSheet("background-color: rgb(0, 255, 127);")
        self.comboBox_2.setObjectName("comboBox_2")
        self.comboBox_2.addItem("")
        self.comboBox_2.addItem("")
        self.comboBox_2.addItem("")
        self.comboBox_2.addItem("")
        self.comboBox_2.addItem("")
        self.comboBox_2.addItem("")
        MainWindow.setCentralWidget(self.centralwidget)
        self.statusbar = QtWidgets.QStatusBar(MainWindow)
        self.statusbar.setObjectName("statusbar")
        MainWindow.setStatusBar(self.statusbar)

        self.retranslateUi(MainWindow)
        QtCore.QMetaObject.connectSlotsByName(MainWindow)

    def retranslateUi(self, MainWindow):
        _translate = QtCore.QCoreApplication.translate
        MainWindow.setWindowTitle(_translate("MainWindow", "MainWindow"))
        self.pushButton.setText(_translate("MainWindow", "Load"))
        self.comboBox.setItemText(0, _translate("MainWindow", "Quick Sort"))
        self.comboBox.setItemText(1, _translate("MainWindow", "Merge Sort"))
        self.comboBox.setItemText(2, _translate("MainWindow", "Heap Sort"))
        self.comboBox.setItemText(3, _translate("MainWindow", "Insertion Sort"))
        self.comboBox.setItemText(4, _translate("MainWindow", "Counting Sort"))
        self.comboBox.setItemText(5, _translate("MainWindow", "Bubble Sort"))
        self.comboBox.setItemText(6, _translate("MainWindow", "Selection Sort"))
        self.label.setText(_translate("MainWindow", " Sorting Methods"))
        self.pushButton_2.setText(_translate("MainWindow", "Scrap"))
        self.pushButton_3.setText(_translate("MainWindow", "Pause"))
        self.pushButton_4.setText(_translate("MainWindow", "Resume"))
        self.pushButton_5.setText(_translate("MainWindow", "Sort"))
        self.label_2.setText(_translate("MainWindow", "  Other"))
        self.comboBox_2.setItemText(0, _translate("MainWindow", "Ascending"))
        self.comboBox_2.setItemText(1, _translate("MainWindow", "Descending"))
        self.comboBox_2.setItemText(2, _translate("MainWindow", "Starts With"))
        self.comboBox_2.setItemText(3, _translate("MainWindow", "Ends With"))
        self.comboBox_2.setItemText(4, _translate("MainWindow", "Contains "))
        self.comboBox_2.setItemText(5, _translate("MainWindow", "Is Empty"))
    def run(self, n):
        for i in range(n):
            time.sleep(1)
            self.progressBar.setValue(i+1)
    def loadData(self):
        ram=[]
        model=[]
        price=[]
        camera=[]
        ratings=[]
        display=[]
        battery=[]
        
        with open('Products.csv', mode ='r')as file:
            csvFile = csv.reader(file)

            for lines in csvFile:
                model.append(lines[0])
                ratings.append(lines[1])
                ram.append(lines[2])
                display.append(lines[3])
                camera.append(lines[4])
                battery.append(lines[5])
                price.append(lines[6])
                
        row=0
        self.tableWidget.setRowCount(len(model))
        for mod in model:
            self.tableWidget.setItem(row, 0, QtWidgets.QTableWidgetItem(mod))
            row=row+1
        row=0
        for rat in ratings:
            self.tableWidget.setItem(row, 6, QtWidgets.QTableWidgetItem(rat))
            row=row+1
        row=0
        for ra in ram:
            self.tableWidget.setItem(row, 2, QtWidgets.QTableWidgetItem(ra))
            row=row+1
        row=0
        for dis in display:
            self.tableWidget.setItem(row, 3, QtWidgets.QTableWidgetItem(dis))
            row=row+1
        row=0
        for cam in camra:
            self.tableWidget.setItem(row, 4, QtWidgets.QTableWidgetItem(cam))
            row=row+1
        row=0
        for bat in battery:
            self.tableWidget.setItem(row, 5, QtWidgets.QTableWidgetItem(bat))
            row=row+1
        row=0
        for pr in price:
            self.tableWidget.setItem(row, 1, QtWidgets.QTableWidgetItem(pri))
            row=row+1
    def scrap(self):
        template = 'https://www.flipkart.com/search?q={}&as=on&as-show=on&otracker=AS_Query_HistoryAutoSuggest_1_4_na_na_na&otracker1=AS_Query_HistoryAutoSuggest_1_4_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=mobile+phones&requestId=e625b409-ca2a-456a-b53c-0fdb7618b658&as-backfill=on'
        search_item = 'mobile phones'
        search_item = search_item.replace(" ","+")
        url = template.format(search_item)
        url += '&page{}'
        driver = webdriver.Chrome(executable_path='C:\Program Files\chromedriver.exe')
        mobiles = []
        for page in range(1,464):
            driver.get(url.format(page))
            soup = BeautifulSoup(driver.page_source,'html.parser')
            results = soup.find_all('a',{'class':"_1fQZEK"})
            for item in results:
                model = item.find('div',{'class':"_4rR01T"}).text
                star = item.find('div',{'class':"_3LWZlK"}).text
                ram = item.find('li',{'class':"rgWa7D"}).text[0:item.find('li',{'class':"rgWa7D"}).text.find('|')]
                ram = ram[:-7]
                display = item.find_all('li')[1].text.strip()
                camera = item.find_all('li')[2].text.strip()
                battery = item.find_all('li')[3].text
                price = item.find('div',{'class':'_30jeq3 _1_WHN1'}).text
                price = price[1:]
                result = (model,star,ram,display,camera,battery,price)
                mobiles.append(result)
        driver.close()
        with open('E:\\products.csv','w',newline='',encoding='utf-8') as f:
            writer = csv.writer(f)
            writer.writerow(['Model','Ratings','Ram (GB)','Display','Camera','Battery','Price'])
            writer.writerows(mobiles)
    scraped_df = pd.read_csv('E:\\products.csv')
    scraped_df.head()


if __name__ == "__main__":
    app = QtWidgets.QApplication(sys.argv)
    MainWindow = QtWidgets.QMainWindow()
    ui = Ui_MainWindow()
    ui.setupUi(MainWindow)
    MainWindow.show()
    sys.exit(app.exec_())

# %%
def bubbleSort():
    size = len(arr)   
    for i in range(size):
        for j in range(size-i-1):
            if arr[j] > arr[j+1]:
                arr[j],arr[j+1] = arr[j+1],arr[j]

# %%
#Function for Merge Sorting
def mergeSort(arr):
    if len(arr) > 1:
        #Mid of array
        mid = len(arr)//2
        
        #Dividing the array into two halves
        leftArr = arr[:mid]
        rightArr = arr[mid:]

        # Sorting the both halves of array seperatily
        mergeSort(leftArr)
        mergeSort(rightArr)

        i, j, k = 0, 0, 0

        while i < len(leftArr) and j < len(rightArr):
            if leftArr[i] < rightArr[j]:
                arr[k] = leftArr[i]
                i += 1
            else:
                arr[k] = rightArr[j]
                j += 1
            k += 1

        #Checking whether any element is left
        while i < len(leftArr):
            arr[k] = leftArr[i]
            i += 1
            k += 1

        while j < len(rightArr):
            arr[k] = rightArr[j]
            j += 1
            k += 1

# %%
def partition(low, high, arr):
    index = low
    pivot = arr[index]
    
    while low < high:
        while low < len(arr) and arr[low] <= pivot:
            low += 1
            
        while arr[high] > pivot:
            high -= 1
        
        if(low < high):
            arr[low],arr[high] = arr[high],arr[low]

    arr[high],arr[index] = arr[index],arr[high]
    return high
    
def quickSort(low, high, arr):
    if (low < high):
        part = partition(low, high, arr)
        quickSort(low, part - 1, arr)
        quickSort(part + 1, high, arr)

# %%
def insertionSort(arr):
    for i in range(1, len(arr)):
        ele = arr[i]
        j = i-1
        
        while j >= 0 and ele < arr[j]:
            arr[j + 1] = arr[j]
            j -= 1
        arr[j + 1] = ele

# %%
def selectSort(arr):
    for i in range(len(arr)):
        minIdx = i
        for j in range(i+1, len(arr)):
            if arr[minIdx] > arr[j]:
                minIdx = j

        arr[i],arr[minIdx] = arr[minIdx],arr[i]

# %%
def countingSort(arr):
    size = len(arr)
    arr1 = [0] * size
    count = [0] * 10

    for i in range(0, size):
        count[arr[i]] += 1

    for i in range(1, 10):
        count[i] += count[i-1]

    i = size-1
    while i >= 0:
        arr1[count[arr[i]]-1] = arr[i]
        count[arr[i]] -= 1
        i -= 1

    for i in range(0, size):
        arr[i] = arr1[i]
